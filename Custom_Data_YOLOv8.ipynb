# %% [markdown]
# <a href="https://colab.research.google.com/github/SMSajadi99/Custom-Data-YOLOv8-Face-Detection/blob/main/Custom_Data_YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.0/608.0 kB 10.9 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/SMSajadi99/Custom-Data-YOLOv8-Face-Detection.git
# Out:
# Cloning into 'Custom-Data-YOLOv8-Face-Detection'...
# remote: Enumerating objects: 68008, done.
# remote: Counting objects: 100% (31159/31159), done.
# remote: Compressing objects: 100% (30273/30273), done.
# remote: Total 68008 (delta 901), reused 28614 (delta 434), pack-reused 36849
# Receiving objects: 100% (68008/68008), 3.42 GiB | 17.00 MiB/s, done.
# Resolving deltas: 100% (908/908), done.
# Updating files: 100% (48312/48312), done.

# %%
# !nvidia-smi
# Out:
# Wed Jul 26 19:02:43 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/Custom-Data-YOLOv8-Face-Detection/custom.yaml epochs=25 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:01<00:00, 18.6MB/s]
# Ultralytics YOLOv8.0.142 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train3/weights/last.pt" source="/content/Custom-Data-YOLOv8-Face-Detection/images/train/0_Parade_marchingband_1_95.jpg"
# Out:
# Ultralytics YOLOv8.0.142 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# image 1/1 /content/Custom-Data-YOLOv8-Face-Detection/images/train/0_Parade_marchingband_1_95.jpg: 448x640 5 faces, 130.2ms
# Speed: 4.1ms preprocess, 130.2ms inference, 5.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train3/weights/last.pt" source="/content/General_public_preview.mp4"
# Out:
# Ultralytics YOLOv8.0.142 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/608) /content/General_public_preview.mp4: 384x640 5 faces, 108.4ms
# video 1/1 (2/608) /content/General_public_preview.mp4: 384x640 6 faces, 11.1ms
# video 1/1 (3/608) /content/General_public_preview.mp4: 384x640 6 faces, 11.1ms
# video 1/1 (4/608) /content/General_public_preview.mp4: 384x640 5 faces, 11.1ms
# video 1/1 (5/608) /content/General_public_preview.mp4: 384x640 5 faces, 11.1ms
# video 1/1 (6/608) /content/General_public_preview.mp4: 384x640 5 faces, 11.1ms
# video 1/1 (7/608) /content/General_public_preview.mp4: 384x640 5 faces, 11.1ms
# video 1/1 (8/608) /content/General_public_preview.mp4: 384x640 6 faces, 11.1ms
# video 1/1 (9/608) /content/General_public_preview.mp4: 384x640 6 faces, 11.1ms
# video 1/1 (10/608) /content/General_public_preview.mp4: 384x640 6 faces, 11.1ms
# ...
